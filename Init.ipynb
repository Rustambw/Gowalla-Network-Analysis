# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: networkx==3.4.2 in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: community in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 3)) (1.0.0b1)
# Requirement already satisfied: python-louvain in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 4)) (0.16)
# Requirement already satisfied: pip in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 5)) (23.0.1)
# Requirement already satisfied: node2vec==0.5.0 in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /root/venv/lib/python3.10/site-packages (from node2vec==0.5.0->-r ./requirements.txt (line 8)) (4.67.1)
# Requirement already satisfied: gensim<5.0.0,>=4.3.0 in /root/venv/lib/python3.10/site-packages (from node2vec==0.5.0->-r ./requirements.txt (line 8)) (4.3.3)
# Requirement already satisfied: joblib<2.0.0,>=1.4.0 in /root/venv/lib/python3.10/site-packages (from node2vec==0.5.0->-r ./requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /root/venv/lib/python3.10/site-packages (from node2vec==0.5.0->-r ./requirements.txt (line 8)) (1.25.2)
# Requirement already satisfied: Flask in /root/venv/lib/python3.10/site-packages (from community->-r ./requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: requests in /root/venv/lib/python3.10/site-packages (from community->-r ./requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: smart-open>=1.8.1 in /root/venv/lib/python3.10/site-packages (from gensim<5.0.0,>=4.3.0->node2vec==0.5.0->-r ./requirements.txt (line 8)) (6.4.0)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /root/venv/lib/python3.10/site-packages (from gensim<5.0.0,>=4.3.0->node2vec==0.5.0->-r ./requirements.txt (line 8)) (1.9.3)
# Requirement already satisfied: Werkzeug>=3.1 in /root/venv/lib/python3.10/site-packages (from Flask->community->-r ./requirements.txt (line 3)) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /root/venv/lib/python3.10/site-packages (from Flask->community->-r ./requirements.txt (line 3)) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /root/venv/lib/python3.10/site-packages (from Flask->community->-r ./requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /root/venv/lib/python3.10/site-packages (from Flask->community->-r ./requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /root/venv/lib/python3.10/site-packages (from Flask->community->-r ./requirements.txt (line 3)) (8.1.7)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.10/site-packages (from requests->community->-r ./requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.10/site-packages (from requests->community->-r ./requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.10/site-packages (from requests->community->-r ./requirements.txt (line 3)) (2024.12.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.10/site-packages (from requests->community->-r ./requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask->community->-r ./requirements.txt (line 3)) (3.0.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f3935b16-626e-474a-91b2-1c7e75fb9cc3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
